# %%
import paddle

# %%
paddle.utils.run_check()
# Out:
# Running verify PaddlePaddle program ...
# d:\Anaconda\envs\tcc_faturas\lib\site-packages\paddle\pir\math_op_patch.py:219: UserWarning: Value do not have 'place' interface for pir graph mode, try not to use it. None will be returned.
#   warnings.warn(
# PaddlePaddle works well on 1 GPU.
# PaddlePaddle is installed successfully! Let's start deep learning with PaddlePaddle now.

# %%
from paddleocr import PaddleOCR  

ocr = PaddleOCR(
    use_doc_orientation_classify=False, # Disables document orientation classification model via this parameter
    use_doc_unwarping=False, # Disables text image rectification model via this parameter
    use_textline_orientation=False, # Disables text line orientation classification model via this parameter
)
# Out:
# Creating model: ('PP-OCRv5_server_det', None, None)
# Checking connectivity to the model hosters, this may take a while. To bypass this check, set `PADDLE_PDX_DISABLE_MODEL_SOURCE_CHECK` to `True`.
# Using official model (PP-OCRv5_server_det), the model files will be automatically downloaded and saved in `C:\Users\DEVELOPER\.paddlex\official_models\PP-OCRv5_server_det`.
# Fetching 6 files: 100%|██████████| 6/6 [00:02<00:00,  2.15it/s]
# Creating model: ('PP-OCRv5_server_rec', None, None)
# Using official model (PP-OCRv5_server_rec), the model files will be automatically downloaded and saved in `C:\Users\DEVELOPER\.paddlex\official_models\PP-OCRv5_server_rec`.
# Fetching 6 files: 100%|██████████| 6/6 [00:03<00:00,  1.67it/s]

# %%
result = ocr.predict("../data/bitmaps/Nubank_2026-06-08.pdf")  
for res in result:  
    res.print()  
    res.save_to_img("output")  
    res.save_to_json("output")
# Out:
# {'res': {'input_path': '../data/bitmaps/Nubank_2026-06-08.pdf', 'page_index': 0, 'model_settings': {'use_doc_preprocessor': False, 'use_textline_orientation': False}, 'dt_polys': array([[[  86,   69],
#         ...,
#         [  86,  139]],
#
#        ...,
#
#        [[ 981, 1581],
#         ...,
#         [ 981, 1599]]], shape=(9, 4, 2), dtype=int16), 'text_det_params': {'limit_side_len': 64, 'limit_type': 'min', 'thresh': 0.3, 'max_side_limit': 4000, 'box_thresh': 0.6, 'unclip_ratio': 1.5}, 'text_type': 'general', 'textline_orientation_angles': array([-1, ..., -1], shape=(9,)), 'text_rec_score_thresh': 0.0, 'return_word_box': False, 'rec_texts': ['Nu', 'Olá, Luiz.', 'Estaé a sua fatura de', 'junho, no valor de', 'R$1.462,67', 'Data de vencimento: 08 JUN 2026', 'Periodo vigente: O1 MAl a 01 JUN', 'Limite total do cartão de crédito: R$ 11.200,00', '1 de 6'], 'rec_scores': array([0.47143507, ..., 0.87757772], shape=(9,)), 'rec_polys': array([[[  86,   69],
#         ...,
#         [  86,  139]],
#
#        ...,
#
#        [[ 981, 1581],
#         ...,
#         [ 981, 1599]]], shape=(9, 4, 2), dtype=int16), 'rec_boxes': array([[  86, ...,  139],
#        ...,
#        [ 981, ..., 1599]], shape=(9, 4), dtype=int16)}}
# {'res': {'input_path': '../data/bitmaps/Nubank_2026-06-08.pdf', 'page_index': 1, 'model_settings': {'use_doc_preprocessor': False, 'use_textline_orientation': False}, 'dt_polys': array([[[  95,   72],
#         ...,
#         [  95,  134]],
#
#        ...,
#
#        [[1047, 1601],
#         ...,
#         [1047, 1619]]], shape=(72, 4, 2), dtype=int16), 'text_det_params': {'limit_side_len': 64, 'limit_type': 'min', 'thresh': 0.3, 'max_side_limit': 4000, 'box_thresh': 0.6, 'unclip_ratio': 1.5}, 'text_type': 'general', 'textline_orientation_angles': array([-1, ..., -1], shape=(72,)), 'text_rec_score_thresh': 0.0, 'return_word_box': False, 'rec_texts': ['nu', 'LUIZ HENRIQUE MONTEIRO SILVA DE LIMA', 'FATURA 08 JUN 2026', 'EMISSAO E ENVIO 01 JUN 2026', 'Alternativas de pagamento para a sua', 'consulte o aplicativo.', 'fatura no valor de R$ 1.462,67', '1. Pagar o valor total da fatura', 'Voce quita o seu saldo, libera seu limite e não paga juros', 'Pagamento total da fatura', 'nem multa.', 'R$ 1.462,67', '√', 'Sempre a melhor escolha!', 'Não tem juros nem taxas', 'Ainda que pagar a fatura inteira seja a melhor escolha, sabemos que imprevistos acontecem. Aqui, a', 'gente tem opçöes para näo te deixar no atraso. Vocè pode consultar mais no aplicativo.', '2.Parcele a sua fatura', 'Voce dá uma entrada e escolhe o valor', 'Válido até a data de', 'Parcelar em 3', 'Parcelar em 6', 'vencimento da fatura', 'meses', 'meses', 'que cabe no seu bolso, valendo apenas', 'Total a pagar', 'para a fatura atual. Vocè pode parcelar', 'R$ 1.786,12', 'R$ 2.057,85', 'em até 12 vezes. Consulte no aplicativo', 'Valor de entrada', 'R$ 219,40', 'R$ 219,40', 'mais simulaçöes e outras opçöes de', 'Valor da parcela', 'R$ 522,24', 'R$ 306,40', 'parcelamento.', 'Juros totais', '(12,34% a.m.)', 'R$ 312,17', 'R$ 578,32', 'Ideal para quando se precisa de mais tempo para', 'IOF', 'R$ 11,28', 'R$ 16,86', 'pagar.', 'CET', '304,11% ao ano', '304,63% ao ano', '3. Faça o pagamento minimo e entre no rotativo', 'O saldo restante (R$ 1.243,27) entrará nos juros rotativos de', 'Pagamento minimo de', '16,1% ao mês. O valor cresce diariamente, e você pode quitá-lo', 'R$ 219,40', 'quando quiser.', 'Lembre-se: vocè pode pagar', 'Se pagar só na próxima fatura, ficará R$ 1.489,45 [saldo', 'um valor menor de juros', 'quitando antes, parcelando ou', 'restante (R$ 1.243,27) + Juros e lOF (R$ 246,18]. Incluindo o', 'entrando no rotativo com um', 'pagamento minimo que vocè já fez, ficaria R$ 1.78,85.', 'pagamento maior que o valor', 'minimo.', 'Essa opçāoéboa apenas quando voce tem certeza que vai quitar o valor total em', 'poucos dias.', 'Composiçäo do pagamento mínimo: 15% do valor total das compras em aberto da sua fatura atual +', '15% do valor total das compras em aberto mês anterior + 100% de outros lançamentos (juros e mora,', 'multa, IOF, saques e parcelamentos de fatura).', '2 de 6'], 'rec_scores': array([0.69391251, ..., 0.89200264], shape=(72,)), 'rec_polys': array([[[  95,   72],
#         ...,
#         [  95,  134]],
#
#        ...,
#
#        [[1047, 1601],
#         ...,
#         [1047, 1619]]], shape=(72, 4, 2), dtype=int16), 'rec_boxes': array([[  95, ...,  134],
#        ...,
#        [1047, ..., 1619]], shape=(72, 4), dtype=int16)}}
# {'res': {'input_path': '../data/bitmaps/Nubank_2026-06-08.pdf', 'page_index': 2, 'model_settings': {'use_doc_preprocessor': False, 'use_textline_orientation': False}, 'dt_polys': array([[[  90,   78],
#         ...,
#         [  90,  148]],
#
#        ...,
#
#        [[1053, 1627],
#         ...,
#         [1053, 1642]]], shape=(28, 4, 2), dtype=int16), 'text_det_params': {'limit_side_len': 64, 'limit_type': 'min', 'thresh': 0.3, 'max_side_limit': 4000, 'box_thresh': 0.6, 'unclip_ratio': 1.5}, 'text_type': 'general', 'textline_orientation_angles': array([-1, ..., -1], shape=(28,)), 'text_rec_score_thresh': 0.0, 'return_word_box': False, 'rec_texts': ['Nu', 'LUIZ HENRIQUE MONTEIRO SILVA DE LIMA', 'FATURA 08 JUN 2026', 'EMISSAO E ENVIO 01 JUN 2026', '4. Pagar menos que o valor minimo e deixar a fatura atrasar', 'Ao pagar um valor menor que o pagamento minimo de R$ 219,40, ou não efetuar nenhum pagamento.', 'voce entrará em atraso. Além de todos os encargos como juros, lOF e multa, voce ainda corre o risco', 'de ter seu cartäo bloqueado e seu CPF negativado.', 'Nuncaéumaboaescolha.Voceconsegueparcelarumvalorquecaibanoseubolsonoaplicativo.', 'Nu Pagamentos S.A.', 'SAC 4020 0182', 'Encargos e Custo Efetivo Total (CET) válidos para o proximo periodo', 'CNPJ 18.236.120/0001-58', 'capitais e regioes metropolitanas', 'Rua Capote Valente, 39 -Pinheiros', '0800591 2117', 'Sague nacional juros de 9,75% a.m + lOF de 0,38% + lOF diario até o vencimento de 0.008%', 'São Paulo/SP -05409-000', 'demais localidades', 'e CET maximo do emprestimo de 289,42% a.a', 'Ouvidoria 0800 887 0463', 'Saque internacional juros de 9,75% a.m +lOF de 0,38% +IOF diario até o vencimento de', '0.008% +lOF de cambio de 3.5% e CET maximo do empréstimo de 289,42% a.a', '8h às 18h em dias úteis', 'Juros rotativo 16,1% ao mes CET 503,15% ao ano', 'Juros de parcelamento do saldo devedor da fatura consulte o app na contratacao', 'Juros e mora em caso de atraso 17,1% ao mes +2% multa CET:570,17% ao ano', '3de 6'], 'rec_scores': array([0.50957763, ..., 0.96999979], shape=(28,)), 'rec_polys': array([[[  90,   78],
#         ...,
#         [  90,  148]],
#
#        ...,
#
#        [[1053, 1627],
#         ...,
#         [1053, 1642]]], shape=(28, 4, 2), dtype=int16), 'rec_boxes': array([[  90, ...,  148],
#        ...,
#        [1053, ..., 1642]], shape=(28, 4), dtype=int16)}}
# {'res': {'input_path': '../data/bitmaps/Nubank_2026-06-08.pdf', 'page_index': 3, 'model_settings': {'use_doc_preprocessor': False, 'use_textline_orientation': False}, 'dt_polys': array([[[  91,   69],
#         ...,
#         [  91,  138]],
#
#        ...,
#
#        [[1052, 1625],
#         ...,
#         [1052, 1644]]], shape=(43, 4, 2), dtype=int16), 'text_det_params': {'limit_side_len': 64, 'limit_type': 'min', 'thresh': 0.3, 'max_side_limit': 4000, 'box_thresh': 0.6, 'unclip_ratio': 1.5}, 'text_type': 'general', 'textline_orientation_angles': array([-1, ..., -1], shape=(43,)), 'text_rec_score_thresh': 0.0, 'return_word_box': False, 'rec_texts': ['∩u', 'LUIZ HENRIQUE MONTEIRO SILVA DE LIMA', 'FATURA 08 JUN 2026', 'EMISSAO E ENVIO 01 JUN 2026', 'RESUMO DA FATURA ATUAL', 'Fatura anterior', 'R$ 3.142,79', 'Pagamento recebido', '-R$ 3.142,79', 'Total de compras de todos os cartöes, O1 MAl a 01 JUN', 'R$ 1.462,67', 'Total a pagar', 'R$ 1.462,67', 'Pagamento mínimo para nao ficar em atraso', 'R$ 219,40', 'O Nubank declara, nos termos da Lei 12.007 2009, gue os débitos referentes ao cartao de crédito no ano de 2025', 'foram deyidamente guitados Fsta declaracao substitui os comprovantes dos pagamentos dos anos anteriores.assim', 'como, aqueles pagamentos realizados até a data de vencimento da fatura de dezembro de 225.', 'PROXIMAS FATURAS', 'Fechamento da próxima fatura', '01 JUL 2026', 'Saldo em aberto da próxima fatura', 'R$ 338,82', 'Saldo em aberto total', 'R$ 483,42', 'LIMITES DISPONIVEIS', 'Utilizado', 'Disponivel', 'Limite total', 'R$ 1.946,9', 'R$ 11.200,00', 'VALOR MAXIMO PARA TRANSAÇOES', 'Valor máximo', 'Saque no crédito', 'R$ 1.680,00', 'Pix no crédito', 'R$ 11.200,00', 'Pagamentos de boleto no crédito', 'R$ 11.200,00', 'As informaçōes de limite sāo referentes ao periodo desta fatura, especificamente na data de emissao da fatura (01/6/226) as 03:40. Para', 'informaçōes atualizadas em tempo real, consulte o aplicativo do Nu. O valor do Limite Adicional naoé fixo e pode variar de acordo com as nossas', 'analises,podendo inclusive ser removido.', '4de 6'], 'rec_scores': array([0.51393151, ..., 0.95983344], shape=(43,)), 'rec_polys': array([[[  91,   69],
#         ...,
#         [  91,  138]],
#
#        ...,
#
#        [[1052, 1625],
#         ...,
#         [1052, 1644]]], shape=(43, 4, 2), dtype=int16), 'rec_boxes': array([[  91, ...,  138],
#        ...,
#        [1052, ..., 1644]], shape=(43, 4), dtype=int16)}}
# {'res': {'input_path': '../data/bitmaps/Nubank_2026-06-08.pdf', 'page_index': 4, 'model_settings': {'use_doc_preprocessor': False, 'use_textline_orientation': False}, 'dt_polys': array([[[  90,   69],
#         ...,
#         [  90,  138]],
#
#        ...,
#
#        [[1050, 1623],
#         ...,
#         [1050, 1645]]], shape=(94, 4, 2), dtype=int16), 'text_det_params': {'limit_side_len': 64, 'limit_type': 'min', 'thresh': 0.3, 'max_side_limit': 4000, 'box_thresh': 0.6, 'unclip_ratio': 1.5}, 'text_type': 'general', 'textline_orientation_angles': array([-1, ..., -1], shape=(94,)), 'text_rec_score_thresh': 0.0, 'return_word_box': False, 'rec_texts': ['nu', 'LUIZ HENRIQUE MONTEIRO SILVA DE LIMA', 'FATURA 08 JUN 2026', 'EMISSAO E ENVIO 01 JUN 2026', 'TRANSAÇOES', 'DE01 MALA01 JUN', 'Luiz H M S Lima', 'R$ 1.462,67', '01MAI', '…6039 Drogaria Sao Paulo - Parcela 3/3', 'R$ 140,95', '01 MAI', '…6039 Setor Magazine Calcado - Parcela 3/3', 'R$ 94,99', '01 MAI', 'Yshpcienciada - Parcela 9/12', 'R$ 43,57', '01 MAI', '…6039', 'Drogaria Sao Paulo - Parcela 2/2', 'R$ 78,09', '05 MAI', '…6039', 'Drogaria Sao Paulo - Parcela 1/2', 'R$ 103,58', '06 MAI', '…6039', 'Tim*Tim', 'R$ 20,00', '11 MAI', '…6039', 'Avicolaquitandae', 'R$ 15,00', '11 MAI', '…6039', 'Mp *Jhoonymorango', 'R$ 15,00', '11 MAI', ' …6039 Jose Hortifruti', 'R$ 14,00', '14 MAI', '□…6039', 'Drogaria Paulista Lj60', 'R$ 10,99', '15 MAI', '…6039', 'Estacao Foto e lmagem', 'R$ 10,00', '16 MAI', '□…6039', 'Drogaria Sao Paulo', 'R$ 57,59', '18 MAI', ' …6039 Avicolaquitandae', 'R$ 20,00', '18 MAI', '□…6039', 'Leandroferreirada', 'R$ 30,00', '18 MAI', '…6039', 'Avicolaquitandae', 'R$ 15,00', '20 MAI', '…6039', 'DI *Uberrides', 'R$ 11,97', '20 MAI', '…6039', 'Supermercado Takahashi', 'R$ 44,71', '20 MAI', '…6039 DI*Uberrides', 'R$ 12,98', '21 MAI', ' …6039 Supermercado Takahashi', 'R$ 73,85', '22 MAI', '…6039', 'Supermercado X Loja', 'R$ 50,88', '22 MAI', '…6039 Drogaria Sao Paulo - Parcela 1/2', 'R$ 104,22', '23 MAI', ' …6039 Supermercado Takahashi', 'R$ 55,42', '25 MAI', '…6039 Mp *Jhoonymorango', 'R$ 20,00', '25 MAI', '…6039 Leandroferreirada', 'R$ 28,00', '5 de 6'], 'rec_scores': array([0.65251255, ..., 0.91585726], shape=(94,)), 'rec_polys': array([[[  90,   69],
#         ...,
#         [  90,  138]],
#
#        ...,
#
#        [[1050, 1623],
#         ...,
#         [1050, 1645]]], shape=(94, 4, 2), dtype=int16), 'rec_boxes': array([[  90, ...,  138],
#        ...,
#        [1050, ..., 1645]], shape=(94, 4), dtype=int16)}}
# {'res': {'input_path': '../data/bitmaps/Nubank_2026-06-08.pdf', 'page_index': 5, 'model_settings': {'use_doc_preprocessor': False, 'use_textline_orientation': False}, 'dt_polys': array([[[  90,   68],
#         ...,
#         [  90,  138]],
#
#        ...,
#
#        [[1052, 1625],
#         ...,
#         [1052, 1644]]], shape=(51, 4, 2), dtype=int16), 'text_det_params': {'limit_side_len': 64, 'limit_type': 'min', 'thresh': 0.3, 'max_side_limit': 4000, 'box_thresh': 0.6, 'unclip_ratio': 1.5}, 'text_type': 'general', 'textline_orientation_angles': array([-1, ..., -1], shape=(51,)), 'text_rec_score_thresh': 0.0, 'return_word_box': False, 'rec_texts': ['Nu', 'LUIZ HENRIQUE MONTEIRO SILVA DE LIMA', 'FATURA 08 JUN 2026', 'EMISSAO E ENVIO 01 JUN 2026', 'TRANSAÇÖES', 'DE01 MALA01 JUN', '25 MAI', '…6039 Avicolaquitandae', 'R$ 15,00', '25 MAI', '…6039', 'Supermercado Takahashi', 'R$ 58,15', '26 MAI', ' …6039', 'Supermercado Takahashi', 'R$ 57,97', '27 MAI', '□…6039 Supermercado Takahashi', 'R$ 61,46', '28 MAI', '□…6039', 'Supermercado Takahashi', 'R$ 68,95', '29 MAI', ' …6039 Drogaria Paulista Lj60', 'R$ 10,99', '29 MAI', '…6039 Supermercado Takahashi', 'R$ 61,90', '31 MAI', '…6039 Drogaria Sao Paulo - Parcela 1/3', 'R$ 57,46', 'Pagamentos e Financiamentos', '-R$ 3.142,79', '04 MAI', 'Pagamento em 04 MAI', '-R$ 3.142,79', '08 MAI', 'Saldo restante da fatura anterior', 'R$ 0,00', '08 MAI', 'Saldo restante da fatura anterior', 'R$ 0,00', 'Em cumprimento à regulaçao do Banco Central, as suas operaçōes de crédito, estejam elas em dia ou atrasadas, serao comunicados ao Sistema', 'de Informacōes de Créditos (ScR) e poderao ser consultadas no registrato, pelo Meu BC com sua Conta gov.br, que voce pode acessar fazendo o', 'login com sua conta Nubank.', 'Como assegurado pela Resoluçao CMN n°5.112 de 21/12/2023,o valor total cobrado a titulo de juros e encargos financeiros aplicados aos', 'financiamentos de saldo devedor da fatura (rotativo, parcelamentos de fatura e renegociacōes de pendencias) nao deve exceder o valor original', 'da divida. Válido apenas para as operaçōes realizadas a partir de 3 de Janeiro de 2024.', '6de 6'], 'rec_scores': array([0.55351484, ..., 0.95466101], shape=(51,)), 'rec_polys': array([[[  90,   68],
#         ...,
#         [  90,  138]],
#
#        ...,
#
#        [[1052, 1625],
#         ...,
#         [1052, 1644]]], shape=(51, 4, 2), dtype=int16), 'rec_boxes': array([[  90, ...,  138],
#        ...,
#        [1052, ..., 1644]], shape=(51, 4), dtype=int16)}}
